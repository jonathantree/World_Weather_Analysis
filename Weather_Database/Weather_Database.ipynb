# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
import os
import time
from datetime import datetime

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Current Weather" : weather_desc
                         
                         })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuatapere
# Processing Record 2 of Set 1 | teul
# City not found. Skipping...
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | dicabisagan
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | lagos
# Processing Record 7 of Set 1 | sao joao da barra
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | san quintin
# Processing Record 10 of Set 1 | hilo
# Processing Record 11 of Set 1 | cabo san lucas
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | deputatskiy
# Processing Record 14 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 1 | chuy
# Processing Record 17 of Set 1 | sabla
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | vaini
# Processing Record 20 of Set 1 | naze
# Processing Record 21 of Set 1 | balkanabat
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | brae
# Processing Record 24 of Set 1 | aklavik
# Processing Record 25 of Set 1 | touros
# Processing Record 26 of Set 1 | burica
# City not found. Skipping...
# Processing Record 27 of Set 1 | kieta
# Processing Record 28 of Set 1 | ribeira grande
# Processing Record 29 of Set 1 | kapaa
# Processing Record 30 of Set 1 | iqaluit
# Processing Record 31 of Set 1 | georgetown
# Processing Record 32 of Set 1 | tarrafal
# Processing Record 33 of Set 1 | port alfred
# Processing Record 34 of Set 1 | nanortalik
# Processing Record 35 of Set 1 | guerrero negro
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | cameron park
# Processing Record 38 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 1 | mezen
# Processing Record 40 of Set 1 | asau
# Processing Record 41 of Set 1 | pontianak
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | makueni
# Processing Record 46 of Set 1 | saint george
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | kloulklubed
# Processing Record 49 of Set 1 | cidreira
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | taoudenni
# Processing Record 4 of Set 2 | hobart
# Processing Record 5 of Set 2 | vanimo
# Processing Record 6 of Set 2 | hasaki
# Processing Record 7 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 8 of Set 2 | qaanaaq
# Processing Record 9 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 11 of Set 2 | butaritari
# Processing Record 12 of Set 2 | longyearbyen
# Processing Record 13 of Set 2 | filimonovo
# Processing Record 14 of Set 2 | katsuura
# Processing Record 15 of Set 2 | alofi
# Processing Record 16 of Set 2 | vardo
# Processing Record 17 of Set 2 | kaitangata
# Processing Record 18 of Set 2 | avarua
# Processing Record 19 of Set 2 | longlac
# City not found. Skipping...
# Processing Record 20 of Set 2 | hofn
# Processing Record 21 of Set 2 | hegang
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 2 | khorol
# Processing Record 25 of Set 2 | portel
# Processing Record 26 of Set 2 | synya
# Processing Record 27 of Set 2 | vologda
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | sindgi
# Processing Record 30 of Set 2 | riyadh
# Processing Record 31 of Set 2 | bilma
# Processing Record 32 of Set 2 | san francisco
# Processing Record 33 of Set 2 | cockburn town
# Processing Record 34 of Set 2 | faya
# Processing Record 35 of Set 2 | mutsamudu
# City not found. Skipping...
# Processing Record 36 of Set 2 | mataura
# Processing Record 37 of Set 2 | skagastrond
# City not found. Skipping...
# Processing Record 38 of Set 2 | victoria
# Processing Record 39 of Set 2 | karratha
# Processing Record 40 of Set 2 | wellington
# Processing Record 41 of Set 2 | carballo
# Processing Record 42 of Set 2 | port elizabeth
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | etah
# Processing Record 45 of Set 2 | hermanus
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | rudnogorsk
# Processing Record 48 of Set 2 | serenje
# Processing Record 49 of Set 2 | mergui
# City not found. Skipping...
# Processing Record 50 of Set 2 | okato
# Processing Record 1 of Set 3 | sitka
# Processing Record 2 of Set 3 | gangotri
# City not found. Skipping...
# Processing Record 3 of Set 3 | tilichiki
# Processing Record 4 of Set 3 | cap-aux-meules
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | nikolskoye
# Processing Record 7 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | chokurdakh
# Processing Record 11 of Set 3 | barrow
# Processing Record 12 of Set 3 | ambulu
# Processing Record 13 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 3 | dunedin
# Processing Record 15 of Set 3 | narsaq
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | faanui
# Processing Record 18 of Set 3 | hauterive
# Processing Record 19 of Set 3 | meyungs
# City not found. Skipping...
# Processing Record 20 of Set 3 | leningradskiy
# Processing Record 21 of Set 3 | farmington
# Processing Record 22 of Set 3 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 3 | natal
# Processing Record 24 of Set 3 | saint-pierre
# Processing Record 25 of Set 3 | arraial do cabo
# Processing Record 26 of Set 3 | makakilo city
# Processing Record 27 of Set 3 | chagda
# City not found. Skipping...
# Processing Record 28 of Set 3 | salinopolis
# Processing Record 29 of Set 3 | thompson
# Processing Record 30 of Set 3 | esperance
# Processing Record 31 of Set 3 | chunoyar
# Processing Record 32 of Set 3 | college
# Processing Record 33 of Set 3 | matara
# Processing Record 34 of Set 3 | eskil
# Processing Record 35 of Set 3 | te anau
# Processing Record 36 of Set 3 | vakhrushev
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | kavieng
# Processing Record 39 of Set 3 | porto novo
# Processing Record 40 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 41 of Set 3 | takoradi
# Processing Record 42 of Set 3 | chitral
# Processing Record 43 of Set 3 | akom
# Processing Record 44 of Set 3 | lokosovo
# Processing Record 45 of Set 3 | nizhneudinsk
# Processing Record 46 of Set 3 | bratsk
# Processing Record 47 of Set 3 | lavrentiya
# Processing Record 48 of Set 3 | huangcun
# Processing Record 49 of Set 3 | egvekinot
# Processing Record 50 of Set 3 | mecca
# Processing Record 1 of Set 4 | banda aceh
# Processing Record 2 of Set 4 | maceio
# Processing Record 3 of Set 4 | albany
# Processing Record 4 of Set 4 | mount gambier
# Processing Record 5 of Set 4 | richards bay
# Processing Record 6 of Set 4 | maba
# Processing Record 7 of Set 4 | rocha
# Processing Record 8 of Set 4 | mindelo
# Processing Record 9 of Set 4 | san juan
# Processing Record 10 of Set 4 | severodvinsk
# Processing Record 11 of Set 4 | bedele
# Processing Record 12 of Set 4 | neuquen
# Processing Record 13 of Set 4 | beliator
# Processing Record 14 of Set 4 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 4 | djougou
# Processing Record 16 of Set 4 | cherskiy
# Processing Record 17 of Set 4 | lata
# Processing Record 18 of Set 4 | boa viagem
# Processing Record 19 of Set 4 | vila velha
# Processing Record 20 of Set 4 | yar-sale
# Processing Record 21 of Set 4 | puerto ayora
# Processing Record 22 of Set 4 | coquimbo
# Processing Record 23 of Set 4 | tra vinh
# Processing Record 24 of Set 4 | nyurba
# Processing Record 25 of Set 4 | baracoa
# Processing Record 26 of Set 4 | roebourne
# Processing Record 27 of Set 4 | anadyr
# Processing Record 28 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | usisha
# Processing Record 31 of Set 4 | vyshkov
# Processing Record 32 of Set 4 | emba
# Processing Record 33 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 4 | peleduy
# Processing Record 35 of Set 4 | chaumont
# Processing Record 36 of Set 4 | vao
# Processing Record 37 of Set 4 | westport
# Processing Record 38 of Set 4 | yerbogachen
# Processing Record 39 of Set 4 | gryazi
# Processing Record 40 of Set 4 | tlahualilo
# City not found. Skipping...
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | raca
# Processing Record 44 of Set 4 | bonthe
# Processing Record 45 of Set 4 | tombouctou
# Processing Record 46 of Set 4 | broken hill
# Processing Record 47 of Set 4 | pilot butte
# Processing Record 48 of Set 4 | raduzhnyy
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | belaya gora
# Processing Record 1 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 5 | port hueneme
# Processing Record 3 of Set 5 | krasnoarmeysk
# Processing Record 4 of Set 5 | moindou
# Processing Record 5 of Set 5 | geraldton
# Processing Record 6 of Set 5 | cuamba
# Processing Record 7 of Set 5 | padang
# Processing Record 8 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 5 | sola
# Processing Record 10 of Set 5 | cayenne
# Processing Record 11 of Set 5 | castro
# Processing Record 12 of Set 5 | tela
# Processing Record 13 of Set 5 | fairbanks
# Processing Record 14 of Set 5 | belgrade
# Processing Record 15 of Set 5 | talnakh
# Processing Record 16 of Set 5 | sena madureira
# Processing Record 17 of Set 5 | ilulissat
# Processing Record 18 of Set 5 | wattegama
# Processing Record 19 of Set 5 | san jose
# Processing Record 20 of Set 5 | teguldet
# Processing Record 21 of Set 5 | khatanga
# Processing Record 22 of Set 5 | abonnema
# Processing Record 23 of Set 5 | bull savanna
# Processing Record 24 of Set 5 | severo-kurilsk
# Processing Record 25 of Set 5 | krutikha
# Processing Record 26 of Set 5 | marsa matruh
# Processing Record 27 of Set 5 | fukue
# Processing Record 28 of Set 5 | klaksvik
# Processing Record 29 of Set 5 | belmonte
# Processing Record 30 of Set 5 | half moon bay
# Processing Record 31 of Set 5 | namibe
# Processing Record 32 of Set 5 | hibbing
# Processing Record 33 of Set 5 | ninh binh
# Processing Record 34 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 5 | maumere
# Processing Record 36 of Set 5 | athens
# Processing Record 37 of Set 5 | pevek
# Processing Record 38 of Set 5 | ust-ishim
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | port hedland
# Processing Record 41 of Set 5 | nome
# Processing Record 42 of Set 5 | port-gentil
# Processing Record 43 of Set 5 | upernavik
# Processing Record 44 of Set 5 | segou
# Processing Record 45 of Set 5 | shillong
# Processing Record 46 of Set 5 | shubarshi
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | shingu
# Processing Record 49 of Set 5 | vila do maio
# Processing Record 50 of Set 5 | nizhniy baskunchak
# Processing Record 1 of Set 6 | bengkulu
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | plettenberg bay
# Processing Record 4 of Set 6 | libreville
# Processing Record 5 of Set 6 | karera
# Processing Record 6 of Set 6 | dingle
# Processing Record 7 of Set 6 | sao filipe
# Processing Record 8 of Set 6 | rawson
# Processing Record 9 of Set 6 | awbari
# Processing Record 10 of Set 6 | maine-soroa
# Processing Record 11 of Set 6 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 6 | port shepstone
# Processing Record 13 of Set 6 | qaqortoq
# Processing Record 14 of Set 6 | alyangula
# Processing Record 15 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 16 of Set 6 | sao felix do xingu
# Processing Record 17 of Set 6 | mercedes
# Processing Record 18 of Set 6 | maragogi
# Processing Record 19 of Set 6 | santa helena
# Processing Record 20 of Set 6 | rassvet
# Processing Record 21 of Set 6 | pokrovsk
# Processing Record 22 of Set 6 | pacific grove
# Processing Record 23 of Set 6 | svetlogorsk
# Processing Record 24 of Set 6 | maniitsoq
# Processing Record 25 of Set 6 | lagunas
# Processing Record 26 of Set 6 | hokitika
# Processing Record 27 of Set 6 | mari-turek
# Processing Record 28 of Set 6 | erenhot
# Processing Record 29 of Set 6 | buturlino
# Processing Record 30 of Set 6 | henties bay
# Processing Record 31 of Set 6 | zhezkazgan
# Processing Record 32 of Set 6 | teya
# Processing Record 33 of Set 6 | salalah
# Processing Record 34 of Set 6 | norman wells
# Processing Record 35 of Set 6 | selje
# Processing Record 36 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 37 of Set 6 | doha
# Processing Record 38 of Set 6 | saint-augustin
# Processing Record 39 of Set 6 | puerto leguizamo
# Processing Record 40 of Set 6 | aswan
# Processing Record 41 of Set 6 | salamiyah
# Processing Record 42 of Set 6 | dali
# Processing Record 43 of Set 6 | davila
# Processing Record 44 of Set 6 | yagodnoye
# Processing Record 45 of Set 6 | siuna
# Processing Record 46 of Set 6 | ascension
# Processing Record 47 of Set 6 | mahebourg
# Processing Record 48 of Set 6 | charyshskoye
# Processing Record 49 of Set 6 | luderitz
# Processing Record 50 of Set 6 | bad krozingen
# Processing Record 1 of Set 7 | constitucion
# Processing Record 2 of Set 7 | bethanien
# Processing Record 3 of Set 7 | baykit
# Processing Record 4 of Set 7 | warri
# Processing Record 5 of Set 7 | malyn
# Processing Record 6 of Set 7 | conde
# Processing Record 7 of Set 7 | mogadishu
# Processing Record 8 of Set 7 | falam
# Processing Record 9 of Set 7 | gushikawa
# Processing Record 10 of Set 7 | bristol
# Processing Record 11 of Set 7 | namatanai
# Processing Record 12 of Set 7 | dudinka
# Processing Record 13 of Set 7 | san ramon de la nueva oran
# Processing Record 14 of Set 7 | bridgton
# Processing Record 15 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 16 of Set 7 | labuhan
# Processing Record 17 of Set 7 | husavik
# Processing Record 18 of Set 7 | ishigaki
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | pinotepa nacional
# Processing Record 21 of Set 7 | rudbar
# Processing Record 22 of Set 7 | guarumal
# Processing Record 23 of Set 7 | aban
# Processing Record 24 of Set 7 | bambanglipuro
# Processing Record 25 of Set 7 | chipinge
# Processing Record 26 of Set 7 | yulara
# Processing Record 27 of Set 7 | caravelas
# Processing Record 28 of Set 7 | taubate
# Processing Record 29 of Set 7 | mukhen
# Processing Record 30 of Set 7 | port hardy
# Processing Record 31 of Set 7 | beringovskiy
# Processing Record 32 of Set 7 | codrington
# Processing Record 33 of Set 7 | paamiut
# Processing Record 34 of Set 7 | carnarvon
# Processing Record 35 of Set 7 | kruisfontein
# Processing Record 36 of Set 7 | beloha
# Processing Record 37 of Set 7 | lorengau
# Processing Record 38 of Set 7 | belyy yar
# Processing Record 39 of Set 7 | sao domingos
# Processing Record 40 of Set 7 | grindavik
# Processing Record 41 of Set 7 | ahuimanu
# Processing Record 42 of Set 7 | potiskum
# Processing Record 43 of Set 7 | masvingo
# Processing Record 44 of Set 7 | ahipara
# Processing Record 45 of Set 7 | kostino
# Processing Record 46 of Set 7 | caracoli
# Processing Record 47 of Set 7 | cassia
# Processing Record 48 of Set 7 | ilhabela
# Processing Record 49 of Set 7 | mendi
# Processing Record 50 of Set 7 | torbay
# Processing Record 1 of Set 8 | pisco
# Processing Record 2 of Set 8 | jumla
# Processing Record 3 of Set 8 | baiyin
# Processing Record 4 of Set 8 | gualaceo
# Processing Record 5 of Set 8 | paracuru
# Processing Record 6 of Set 8 | santos reyes nopala
# Processing Record 7 of Set 8 | bowen
# Processing Record 8 of Set 8 | altay
# Processing Record 9 of Set 8 | wagar
# Processing Record 10 of Set 8 | tautira
# Processing Record 11 of Set 8 | oroville
# Processing Record 12 of Set 8 | sal rei
# Processing Record 13 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 14 of Set 8 | pudozh
# Processing Record 15 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 16 of Set 8 | tiarei
# Processing Record 17 of Set 8 | boa vista
# Processing Record 18 of Set 8 | bonfim
# Processing Record 19 of Set 8 | bandarbeyla
# Processing Record 20 of Set 8 | namtsy
# Processing Record 21 of Set 8 | tasiilaq
# Processing Record 22 of Set 8 | huambo
# Processing Record 23 of Set 8 | visnes
# Processing Record 24 of Set 8 | ciudad bolivar
# Processing Record 25 of Set 8 | nichinan
# Processing Record 26 of Set 8 | wenling
# Processing Record 27 of Set 8 | stornoway
# Processing Record 28 of Set 8 | pangnirtung
# Processing Record 29 of Set 8 | tiksi
# Processing Record 30 of Set 8 | souillac
# Processing Record 31 of Set 8 | waingapu
# Processing Record 32 of Set 8 | goderich
# Processing Record 33 of Set 8 | mount isa
# Processing Record 34 of Set 8 | lompoc
# Processing Record 35 of Set 8 | wajir
# Processing Record 36 of Set 8 | hoquiam
# Processing Record 37 of Set 8 | bastia
# Processing Record 38 of Set 8 | monduli
# Processing Record 39 of Set 8 | oranjemund
# Processing Record 40 of Set 8 | zemlyansk
# Processing Record 41 of Set 8 | chaochou
# City not found. Skipping...
# Processing Record 42 of Set 8 | ponta do sol
# Processing Record 43 of Set 8 | anderson
# Processing Record 44 of Set 8 | shenzhen
# Processing Record 45 of Set 8 | santa rosa
# Processing Record 46 of Set 8 | vila franca do campo
# Processing Record 47 of Set 8 | bulungu
# Processing Record 48 of Set 8 | umea
# Processing Record 49 of Set 8 | kautokeino
# Processing Record 50 of Set 8 | terra santa
# Processing Record 1 of Set 9 | parainen
# Processing Record 2 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 3 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 4 of Set 9 | alta floresta
# Processing Record 5 of Set 9 | awjilah
# Processing Record 6 of Set 9 | kikwit
# Processing Record 7 of Set 9 | talaya
# Processing Record 8 of Set 9 | coos bay
# Processing Record 9 of Set 9 | smithers
# Processing Record 10 of Set 9 | matay
# Processing Record 11 of Set 9 | hohr-grenzhausen
# Processing Record 12 of Set 9 | eyrarbakki
# Processing Record 13 of Set 9 | vallenar
# Processing Record 14 of Set 9 | martapura
# Processing Record 15 of Set 9 | nampula
# Processing Record 16 of Set 9 | san carlos de bariloche
# Processing Record 17 of Set 9 | nishihara
# Processing Record 18 of Set 9 | ridgecrest
# Processing Record 19 of Set 9 | haines junction
# Processing Record 20 of Set 9 | verkhniy lomov
# Processing Record 21 of Set 9 | thinadhoo
# Processing Record 22 of Set 9 | ust-kuyga
# Processing Record 23 of Set 9 | kalengwa
# Processing Record 24 of Set 9 | nha trang
# Processing Record 25 of Set 9 | toktogul
# Processing Record 26 of Set 9 | novomikhaylovskiy
# Processing Record 27 of Set 9 | khoy
# Processing Record 28 of Set 9 | pandavapura
# Processing Record 29 of Set 9 | jiblah
# Processing Record 30 of Set 9 | solnechnyy
# Processing Record 31 of Set 9 | thunder bay
# Processing Record 32 of Set 9 | fredericton
# Processing Record 33 of Set 9 | moba
# Processing Record 34 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 9 | abu dhabi
# Processing Record 36 of Set 9 | meulaboh
# Processing Record 37 of Set 9 | kavaratti
# Processing Record 38 of Set 9 | curitibanos
# Processing Record 39 of Set 9 | savelugu
# Processing Record 40 of Set 9 | tornio
# Processing Record 41 of Set 9 | wanaka
# Processing Record 42 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 43 of Set 9 | shimoda
# Processing Record 44 of Set 9 | barahona
# Processing Record 45 of Set 9 | pyapon
# Processing Record 46 of Set 9 | fort abbas
# Processing Record 47 of Set 9 | fortuna
# Processing Record 48 of Set 9 | suntar
# Processing Record 49 of Set 9 | stromness
# Processing Record 50 of Set 9 | adre
# Processing Record 1 of Set 10 | jinchang
# Processing Record 2 of Set 10 | north platte
# Processing Record 3 of Set 10 | paramonga
# Processing Record 4 of Set 10 | oriximina
# Processing Record 5 of Set 10 | cairns
# Processing Record 6 of Set 10 | cloquet
# Processing Record 7 of Set 10 | rayong
# Processing Record 8 of Set 10 | ossora
# Processing Record 9 of Set 10 | kuusamo
# Processing Record 10 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 10 | frolovo
# Processing Record 12 of Set 10 | inongo
# Processing Record 13 of Set 10 | grand gaube
# Processing Record 14 of Set 10 | symington
# Processing Record 15 of Set 10 | hammerfest
# Processing Record 16 of Set 10 | devils lake
# Processing Record 17 of Set 10 | mitchell
# Processing Record 18 of Set 10 | nemuro
# Processing Record 19 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | zhangjiakou
# Processing Record 21 of Set 10 | dover
# Processing Record 22 of Set 10 | abu samrah
# Processing Record 23 of Set 10 | kudahuvadhoo
# Processing Record 24 of Set 10 | halifax
# Processing Record 25 of Set 10 | fare
# Processing Record 26 of Set 10 | abeche
# Processing Record 27 of Set 10 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 28 of Set 10 | boyolangu
# Processing Record 29 of Set 10 | hobyo
# Processing Record 30 of Set 10 | amparafaravola
# Processing Record 31 of Set 10 | zhanaozen
# Processing Record 32 of Set 10 | poum
# Processing Record 33 of Set 10 | olafsvik
# Processing Record 34 of Set 10 | anloga
# Processing Record 35 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 36 of Set 10 | tromso
# Processing Record 37 of Set 10 | alice springs
# Processing Record 38 of Set 10 | obluche
# City not found. Skipping...
# Processing Record 39 of Set 10 | binay
# Processing Record 40 of Set 10 | nabire
# Processing Record 41 of Set 10 | cabinda
# Processing Record 42 of Set 10 | margate
# Processing Record 43 of Set 10 | labuan
# Processing Record 44 of Set 10 | boguchany
# Processing Record 45 of Set 10 | byron bay
# Processing Record 46 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 47 of Set 10 | dickson
# Processing Record 48 of Set 10 | aripuana
# Processing Record 49 of Set 10 | jaumave
# Processing Record 50 of Set 10 | port lincoln
# Processing Record 1 of Set 11 | tura
# Processing Record 2 of Set 11 | ponta delgada
# Processing Record 3 of Set 11 | akdepe
# Processing Record 4 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 5 of Set 11 | tobol
# Processing Record 6 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 11 | massakory
# Processing Record 8 of Set 11 | taungdwingyi
# Processing Record 9 of Set 11 | gat
# Processing Record 10 of Set 11 | abapo
# Processing Record 11 of Set 11 | chunskiy
# Processing Record 12 of Set 11 | tazovskiy
# Processing Record 13 of Set 11 | kadoma
# Processing Record 14 of Set 11 | shu
# Processing Record 15 of Set 11 | bathsheba
# Processing Record 16 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 17 of Set 11 | praia da vitoria
# Processing Record 18 of Set 11 | kichmengskiy gorodok
# Processing Record 19 of Set 11 | labe
# Processing Record 20 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 21 of Set 11 | pasighat
# Processing Record 22 of Set 11 | mbeya
# Processing Record 23 of Set 11 | champerico
# Processing Record 24 of Set 11 | saurikh
# Processing Record 25 of Set 11 | vestmanna
# Processing Record 26 of Set 11 | san matias
# Processing Record 27 of Set 11 | jaque
# Processing Record 28 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 29 of Set 11 | aneho
# Processing Record 30 of Set 11 | phan thiet
# Processing Record 31 of Set 11 | jaguaruana
# Processing Record 32 of Set 11 | coihaique
# Processing Record 33 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 11 | norsup
# Processing Record 35 of Set 11 | syasstroy
# Processing Record 36 of Set 11 | mapiripan
# Processing Record 37 of Set 11 | amahai
# Processing Record 38 of Set 11 | skagen
# Processing Record 39 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 40 of Set 11 | yatou
# Processing Record 41 of Set 11 | ranau
# Processing Record 42 of Set 11 | sogdiondon
# City not found. Skipping...
# Processing Record 43 of Set 11 | jackson
# Processing Record 44 of Set 11 | nara
# Processing Record 45 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 46 of Set 11 | vidim
# Processing Record 47 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 48 of Set 11 | imeni poliny osipenko
# Processing Record 49 of Set 11 | youghal
# Processing Record 50 of Set 11 | roald
# Processing Record 1 of Set 12 | havre-saint-pierre
# Processing Record 2 of Set 12 | erzin
# Processing Record 3 of Set 12 | petukhovo
# Processing Record 4 of Set 12 | marand
# Processing Record 5 of Set 12 | marawi
# Processing Record 6 of Set 12 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 12 | cruzeiro do sul
# Processing Record 8 of Set 12 | nurobod
# Processing Record 9 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 12 | yeppoon
# Processing Record 11 of Set 12 | mabaruma
# Processing Record 12 of Set 12 | neon karlovasion
# Processing Record 13 of Set 12 | lazurne
# Processing Record 14 of Set 12 | launceston
# Processing Record 15 of Set 12 | palora
# Processing Record 16 of Set 12 | belousovka
# Processing Record 17 of Set 12 | gonbad-e qabus
# Processing Record 18 of Set 12 | chapais
# Processing Record 19 of Set 12 | puerto madero
# Processing Record 20 of Set 12 | votkinsk
# Processing Record 21 of Set 12 | nuuk
# Processing Record 22 of Set 12 | angoche
# Processing Record 23 of Set 12 | chama
# Processing Record 24 of Set 12 | mitsamiouli
# Processing Record 25 of Set 12 | kultayevo
# Processing Record 26 of Set 12 | leh
# Processing Record 27 of Set 12 | ferme-neuve
# Processing Record 28 of Set 12 | sosua
# Processing Record 29 of Set 12 | ust-ilimsk
# Processing Record 30 of Set 12 | itarema
# Processing Record 31 of Set 12 | port blair
# Processing Record 32 of Set 12 | madang
# Processing Record 33 of Set 12 | ndele
# Processing Record 34 of Set 12 | bam
# Processing Record 35 of Set 12 | providencia
# Processing Record 36 of Set 12 | torma
# Processing Record 37 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 38 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 39 of Set 12 | kuytun
# Processing Record 40 of Set 12 | udimskiy
# Processing Record 41 of Set 12 | mayumba
# Processing Record 42 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 43 of Set 12 | kousseri
# Processing Record 44 of Set 12 | negombo
# Processing Record 45 of Set 12 | uhlirske janovice
# Processing Record 46 of Set 12 | vodnyy
# Processing Record 47 of Set 12 | saint-joseph
# Processing Record 48 of Set 12 | sinkat
# City not found. Skipping...
# Processing Record 49 of Set 12 | sioux lookout
# Processing Record 50 of Set 12 | gunjur
# Processing Record 1 of Set 13 | obidos
# Processing Record 2 of Set 13 | mikkeli
# Processing Record 3 of Set 13 | aitape
# Processing Record 4 of Set 13 | vondrozo
# Processing Record 5 of Set 13 | pilar
# Processing Record 6 of Set 13 | los llanos de aridane
# Processing Record 7 of Set 13 | daru
# Processing Record 8 of Set 13 | oyek
# Processing Record 9 of Set 13 | ahmadpur sial
# Processing Record 10 of Set 13 | maroantsetra
# Processing Record 11 of Set 13 | ganzhou
# Processing Record 12 of Set 13 | broome
# Processing Record 13 of Set 13 | xining
# Processing Record 14 of Set 13 | mariel
# Processing Record 15 of Set 13 | flinders
# Processing Record 16 of Set 13 | salinas
# Processing Record 17 of Set 13 | hambantota
# Processing Record 18 of Set 13 | ati
# Processing Record 19 of Set 13 | sudogda
# Processing Record 20 of Set 13 | hvolsvollur
# Processing Record 21 of Set 13 | yumen
# Processing Record 22 of Set 13 | nambucca heads
# Processing Record 23 of Set 13 | nelson bay
# Processing Record 24 of Set 13 | mae ramat
# Processing Record 25 of Set 13 | oyama
# Processing Record 26 of Set 13 | maldonado
# Processing Record 27 of Set 13 | markkleeberg
# Processing Record 28 of Set 13 | tabulbah
# City not found. Skipping...
# Processing Record 29 of Set 13 | rio grande
# Processing Record 30 of Set 13 | warqla
# City not found. Skipping...
# Processing Record 31 of Set 13 | novokayakent
# Processing Record 32 of Set 13 | mananjary
# Processing Record 33 of Set 13 | santiago del estero
# Processing Record 34 of Set 13 | camargo
# Processing Record 35 of Set 13 | airai
# Processing Record 36 of Set 13 | ketchikan
# Processing Record 37 of Set 13 | high prairie
# Processing Record 38 of Set 13 | moussoro
# Processing Record 39 of Set 13 | tanga
# Processing Record 40 of Set 13 | valley city
# Processing Record 41 of Set 13 | san cristobal
# Processing Record 42 of Set 13 | bogorodskoye
# Processing Record 43 of Set 13 | isangel
# Processing Record 44 of Set 13 | umm kaddadah
# Processing Record 45 of Set 13 | port hawkesbury
# Processing Record 46 of Set 13 | cananeia
# Processing Record 47 of Set 13 | abu kamal
# Processing Record 48 of Set 13 | kidal
# Processing Record 49 of Set 13 | kenai
# Processing Record 50 of Set 13 | camacha
# Processing Record 1 of Set 14 | kamaishi
# Processing Record 2 of Set 14 | boali
# Processing Record 3 of Set 14 | morant bay
# Processing Record 4 of Set 14 | glenluce
# Processing Record 5 of Set 14 | york
# Processing Record 6 of Set 14 | verkhnyaya inta
# Processing Record 7 of Set 14 | oistins
# Processing Record 8 of Set 14 | ipora
# Processing Record 9 of Set 14 | tunoshna
# Processing Record 10 of Set 14 | ostrovnoy
# Processing Record 11 of Set 14 | sibolga
# Processing Record 12 of Set 14 | sampit
# Processing Record 13 of Set 14 | buenos aires
# Processing Record 14 of Set 14 | acapulco
# Processing Record 15 of Set 14 | bahia honda
# Processing Record 16 of Set 14 | glendive
# Processing Record 17 of Set 14 | camaqua
# Processing Record 18 of Set 14 | manakara
# Processing Record 19 of Set 14 | jaisalmer
# Processing Record 20 of Set 14 | amapa
# Processing Record 21 of Set 14 | sabya
# Processing Record 22 of Set 14 | lovozero
# Processing Record 23 of Set 14 | russell
# Processing Record 24 of Set 14 | watrous
# Processing Record 25 of Set 14 | yaan
# Processing Record 26 of Set 14 | bella vista
# Processing Record 27 of Set 14 | puri
# Processing Record 28 of Set 14 | almonte
# Processing Record 29 of Set 14 | sharlyk
# Processing Record 30 of Set 14 | umm lajj
# Processing Record 31 of Set 14 | bolobo
# Processing Record 32 of Set 14 | poya
# Processing Record 33 of Set 14 | biak
# Processing Record 34 of Set 14 | aykhal
# Processing Record 35 of Set 14 | kurilsk
# Processing Record 36 of Set 14 | port moresby
# Processing Record 37 of Set 14 | ginda
# Processing Record 38 of Set 14 | trinidad
# Processing Record 39 of Set 14 | maple creek
# Processing Record 40 of Set 14 | yinchuan
# Processing Record 41 of Set 14 | noumea
# Processing Record 42 of Set 14 | bulaevo
# Processing Record 43 of Set 14 | ibipeba
# Processing Record 44 of Set 14 | ugoofaaru
# Processing Record 45 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 46 of Set 14 | muravlenko
# Processing Record 47 of Set 14 | simpang
# Processing Record 48 of Set 14 | baturaja
# Processing Record 49 of Set 14 | moron
# Processing Record 50 of Set 14 | tinskoy
# Processing Record 1 of Set 15 | marsh harbour
# Processing Record 2 of Set 15 | buala
# Processing Record 3 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | koulikoro
# Processing Record 5 of Set 15 | celestun
# Processing Record 6 of Set 15 | adrar
# Processing Record 7 of Set 15 | vikulovo
# Processing Record 8 of Set 15 | sonoita
# Processing Record 9 of Set 15 | one hundred mile house
# City not found. Skipping...
# Processing Record 10 of Set 15 | mazyr
# Processing Record 11 of Set 15 | kupino
# Processing Record 12 of Set 15 | tete
# Processing Record 13 of Set 15 | llangefni
# Processing Record 14 of Set 15 | khair
# Processing Record 15 of Set 15 | miraflores
# Processing Record 16 of Set 15 | san luis
# Processing Record 17 of Set 15 | formoso do araguaia
# City not found. Skipping...
# Processing Record 18 of Set 15 | mao
# Processing Record 19 of Set 15 | miles city
# Processing Record 20 of Set 15 | sorland
# Processing Record 21 of Set 15 | arman
# Processing Record 22 of Set 15 | sabang
# Processing Record 23 of Set 15 | atlantic city
# Processing Record 24 of Set 15 | komsomolskiy
# Processing Record 25 of Set 15 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 15 | rusape
# Processing Record 27 of Set 15 | guiren
# Processing Record 28 of Set 15 | inyonga
# Processing Record 29 of Set 15 | atar
# Processing Record 30 of Set 15 | la libertad
# Processing Record 31 of Set 15 | srednekolymsk
# Processing Record 32 of Set 15 | makung
# City not found. Skipping...
# Processing Record 33 of Set 15 | contamana
# Processing Record 34 of Set 15 | lagoa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 664

# %% [markdown]
# ### Convert the data in the dictionary into a dataframe

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Tuatapere -46.1333  167.6833     58.82        50          20
# 1        East London -33.0153   27.9116     72.97        92          26
# 2        Dicabisagan  17.0818  122.4157     76.71        91         100
# 3       Punta Arenas -53.1500  -70.9167     50.11        76          40
# 4              Lagos   6.5833    3.7500     71.28        95           0
# 5  Sao Joao Da Barra -21.6403  -41.0511     76.05        83           2
# 6            Ushuaia -54.8000  -68.3000     49.66        76          40
# 7        San Quintin  30.4833 -115.9500     59.49        67         100
# 8               Hilo  19.7297 -155.0900     78.53        67          40
# 9     Cabo San Lucas  22.8909 -109.9124     71.51        62           0
#
#    Wind Speed Country                 Date   Current Weather
# 0        9.10      NZ  2022-01-27 01:15:20        few clouds
# 1        2.84      ZA  2022-01-27 01:11:47  scattered clouds
# 2        3.20      PH  2022-01-27 01:15:22     moderate rain
# 3       28.77      CL  2022-01-27 01:15:23  scattered clouds
# 4        0.89      NG  2022-01-27 01:12:04         clear sky
# 5       22.30      BR  2022-01-27 01:15:24         clear sky
# 6       27.63      AR  2022-01-27 01:15:25  scattered clouds
# 7        8.63      MX  2022-01-27 01:15:25   overcast clouds
# 8        9.22      US  2022-01-27 01:12:09  scattered clouds
# 9        1.01      MX  2022-01-27 01:11:35         clear sky

# %%
new_column_order = ["City",
                    "Country",
                    "Date",
                    "Lat",
                    "Lng",
                    "Max Temp",
                    "Humidity",
                    "Cloudiness",
                    "Wind Speed",
                    "Current Weather"]
city_data_df=city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country                 Date      Lat       Lng  Max Temp  \
# 0     Tuatapere      NZ  2022-01-27 01:15:20 -46.1333  167.6833     58.82
# 1   East London      ZA  2022-01-27 01:11:47 -33.0153   27.9116     72.97
# 2   Dicabisagan      PH  2022-01-27 01:15:22  17.0818  122.4157     76.71
# 3  Punta Arenas      CL  2022-01-27 01:15:23 -53.1500  -70.9167     50.11
# 4         Lagos      NG  2022-01-27 01:12:04   6.5833    3.7500     71.28
#
#    Humidity  Cloudiness  Wind Speed   Current Weather
# 0        50          20        9.10        few clouds
# 1        92          26        2.84  scattered clouds
# 2        91         100        3.20     moderate rain
# 3        76          40       28.77  scattered clouds
# 4        95           0        0.89         clear sky

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
